# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\usuario\anaconda3\lib\site-packages (1.1.2)Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Connection parameters
username = "root"
password = "Alexx123."
host = "localhost"
port = 3306  # must be integer
database = "us_project"

# Encode password (safe for special characters)
password_encoded = quote_plus(password)

# Create SQLAlchemy engine
engine = create_engine(
    f"mysql+pymysql://{username}:{password_encoded}@{host}:{port}/{database}",
    connect_args={"local_infile": 1}  # optional for CSV imports
)

print("Connection engine created successfully!")
# Out:
# Connection engine created successfully!

# %%
df = pd.read_csv(
    r"C:\Users\Usuario\Desktop\Analyst Builder\3 MySQL for Data Analytics\11 Full Projects\4 US Household Income Data Cleaning\USHouseholdIncome.csv",
    encoding="latin1"
)
print(df.head())
# Out:
#    row_id     id  State_Code State_Name State_ab          County  \
# 0       1   1026           1    Alabama       AL  Autauga County
# 1       2  10216           1    Alabama       AL  Autauga County
# 2       3  10226           1    Alabama       AL  Autauga County
# 3       4  10236           1    Alabama       AL  Autauga County
# 4       5  10246           1    Alabama       AL  Autauga County
#
#            City         Place   Type Primary  Zip_Code Area_Code      ALand  \
# 0        Elmore  Autaugaville  Track   Track     36025       334    8020338
# 1   Robertsdale  Autaugaville  Track   Track     36567       251  737211648
# 2    Silverhill  Autaugaville  Track   Track     36576       251   71113244
# 3  Orange Beach  Autaugaville  Track   Track     36561       251   15491986
# 4    Louisville  Autaugaville  Track   Track     36048       334  517008078
#
#      AWater        Lat        Lon
# 0     60048  32.447351 -86.476810
# 1   3860933  30.720027 -87.624544
# 2    190587  30.534561 -87.754874
# 3  20427550  30.300586 -87.541798
# 4    983621  31.922275 -85.449831

# %%
#First do the following:
#1 Create a database in MySQL: 
#CREATE DATABASE us_project;
#2 Verify the database exists
#SHOW DATABASES;

# Export to sql
df.to_sql(
    name="us_household_income",   # Table name
    con=engine,
    if_exists="replace",              # or "append" to add without deleting existing
    index=False,                      # Avoid exporting pandas index
    chunksize=1000                    # Handle large datasets in batches
)
# Out:
# 32533
